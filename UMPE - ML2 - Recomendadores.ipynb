# %%
import pandas as pd

# %%
df = pd.read_csv("movies_small.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  userId  movieId  rating   timestamp  \
# 0        1626     132      260     2.0  1157920586
# 1        1647     198      260     5.0  1034137711
# 2        1655     212      260     2.5  1505400094
# 3        1667     234      260     5.0  1004407958
# 4        1684     279      260     5.0  1506394310
#
#                                        title                   genres
# 0  Star Wars: Episode IV - A New Hope (1977)  Action|Adventure|Sci-Fi
# 1  Star Wars: Episode IV - A New Hope (1977)  Action|Adventure|Sci-Fi
# 2  Star Wars: Episode IV - A New Hope (1977)  Action|Adventure|Sci-Fi
# 3  Star Wars: Episode IV - A New Hope (1977)  Action|Adventure|Sci-Fi
# 4  Star Wars: Episode IV - A New Hope (1977)  Action|Adventure|Sci-Fi

# %%
# ¿Cuántas películas vió el usuario 132?

# %%
df['userId']==132
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 251    False
# 252    False
# 253    False
# 254    False
# 255    False
# Name: userId, Length: 256, dtype: bool

# %%
condicion = (df['userId']==132)
df[condicion]
# Out:
#      Unnamed: 0  userId  movieId  rating   timestamp  \
# 0          1626     132      260     2.0  1157920586
# 24         7603     132     1210     2.0  1157921254
# 51        13887     132     2858     4.5  1157922636
# 64        18249     132      914     3.0  1157923450
# 78        26520     132      410     3.0  1157967526
# 104       31294     132      355     2.0  1157923325
# 131       34453     132     1784     2.5  1157921506
# 208       58274     132      788     2.0  1157922765
#
#                                                  title  \
# 0            Star Wars: Episode IV - A New Hope (1977)
# 24   Star Wars: Episode VI - Return of the Jedi (1983)
# 51                              American Beauty (1999)
# 64                                 My Fair Lady (1964)
# 78                         Addams Family Values (1993)
# 104                            Flintstones, The (1994)
# 131                          As Good as It Gets (1997)
# ...

# %%
df[df['userId']==132]
# Out:
#      Unnamed: 0  userId  movieId  rating   timestamp  \
# 0          1626     132      260     2.0  1157920586
# 24         7603     132     1210     2.0  1157921254
# 51        13887     132     2858     4.5  1157922636
# 64        18249     132      914     3.0  1157923450
# 78        26520     132      410     3.0  1157967526
# 104       31294     132      355     2.0  1157923325
# 131       34453     132     1784     2.5  1157921506
# 208       58274     132      788     2.0  1157922765
#
#                                                  title  \
# 0            Star Wars: Episode IV - A New Hope (1977)
# 24   Star Wars: Episode VI - Return of the Jedi (1983)
# 51                              American Beauty (1999)
# 64                                 My Fair Lady (1964)
# 78                         Addams Family Values (1993)
# 104                            Flintstones, The (1994)
# 131                          As Good as It Gets (1997)
# ...

# %%
len(df[df['userId']==132])
# Out:
# 8

# %%
# ¿Cual es el rating promedio del usuario 198?

# %%
df_filtrado = df[df['userId']==198]

# %%
df_filtrado['rating'].mean()
# Out:
# 4.0

# %%
df[df['userId']==573][['movieId','rating']].plot(kind='scatter', x='movieId', y='rating')
# Out:
# <AxesSubplot:xlabel='movieId', ylabel='rating'>

# %%
# ¿Cuales películas vieron los usuarios 573 o 198?
df[(df['userId']==573) | (df['userId']==198)]
# Out:
#      Unnamed: 0  userId  movieId  rating   timestamp  \
# 1          1647     198      260     5.0  1034137711
# 12         1800     573      260     5.0  1186589669
# 15         2171     198      316     5.0  1034135137
# 21         2252     573      316     4.0  1186722532
# 25         7622     198     1210     5.0  1034136682
# 36         7735     573     1210     5.0  1186589710
# 52        13906     198     2858     5.0  1034136008
# 61        14039     573     2858     2.0  1186590377
# 67        19650     198      368     4.0  1034207438
# 92        27499     573       10     4.5  1186722464
# 124       34159     198     1584     4.0  1034135578
# 146       37324     573     5989     4.0  1186589235
# 153       42676     573    72998     5.0  1370377625
# 162       43700     573     1370     4.5  1187044988
# 179       45102     198     4011     3.0  1034207400
# 185       45160     573     4011     4.5  1248841842
# 195       50898     573     3039     4.5  1341798636
# ...

# %%
# ¿Cuales películas en común vieron los usuarios 573 y 198?
df_user_573 = df[(df['userId']==573)]
df_user_198 = df[(df['userId']==198)]
df_merge = df_user_198.merge(df_user_573, on='movieId')[['userId_x','userId_y','rating_x','rating_y','movieId','title_x']]
df_merge
# Out:
#    userId_x  userId_y  rating_x  rating_y  movieId  \
# 0       198       573       5.0       5.0      260
# 1       198       573       5.0       4.0      316
# 2       198       573       5.0       5.0     1210
# 3       198       573       5.0       2.0     2858
# 4       198       573       3.0       4.5     4011
#
#                                              title_x
# 0          Star Wars: Episode IV - A New Hope (1977)
# 1                                    Stargate (1994)
# 2  Star Wars: Episode VI - Return of the Jedi (1983)
# 3                             American Beauty (1999)
# 4                                      Snatch (2000)

# %%
def suma_rara(x,y):
    return 2*x+y
suma_rara(3,4)
# Out:
# 10

# %%
suma_rara(1,4)
# Out:
# 6

# %%
df_merge['diff'] = (df_merge['rating_x'] - df_merge['rating_y'])**2
df_merge
# Out:
#    userId_x  userId_y  rating_x  rating_y  movieId  \
# 0       198       573       5.0       5.0      260
# 1       198       573       5.0       4.0      316
# 2       198       573       5.0       5.0     1210
# 3       198       573       5.0       2.0     2858
# 4       198       573       3.0       4.5     4011
#
#                                              title_x  diff
# 0          Star Wars: Episode IV - A New Hope (1977)  0.00
# 1                                    Stargate (1994)  1.00
# 2  Star Wars: Episode VI - Return of the Jedi (1983)  0.00
# 3                             American Beauty (1999)  9.00
# 4                                      Snatch (2000)  2.25

# %%
import math
math.sqrt(df_merge['diff'].sum())
# Out:
# 3.5

# %%
df_merge.plot(kind='scatter', x='rating_x', y='rating_y')
# Out:
# <AxesSubplot:xlabel='rating_x', ylabel='rating_y'>

# %%
def compare_users(x,y):
    df_user_x = df[(df['userId']==x)]
    df_user_y= df[(df['userId']==y)]
    return df_user_x.merge(df_user_y, on='movieId')[['userId_x','userId_y','rating_x','rating_y','movieId','title_x']]

def plot(df_comodin):
    df_comodin.plot(kind='scatter', x='rating_x', y='rating_y')
    
def distancia(df_comodin):
    suma_cuadrada = (df_comodin['rating_x'] - df_comodin['rating_y'])**2
    return math.sqrt(suma_cuadrada.mean())

# %%
df_merge = compare_users(132, 198)
plot(df_merge)

# %%
compare_users(132, 198)
# Out:
#    userId_x  userId_y  rating_x  rating_y  movieId  \
# 0       132       198       2.0       5.0      260
# 1       132       198       2.0       5.0     1210
# 2       132       198       4.5       5.0     2858
#
#                                              title_x
# 0          Star Wars: Episode IV - A New Hope (1977)
# 1  Star Wars: Episode VI - Return of the Jedi (1983)
# 2                             American Beauty (1999)

# %%
distancia(df_merge)
# Out:
# 2.4664414311581235

# %%
df_merge = compare_users(480,234)
df_merge
# Out:
#    userId_x  userId_y  rating_x  rating_y  movieId  \
# 0       480       234       4.5       5.0      260
# 1       480       234       3.5       5.0     1210
# 2       480       234       2.0       4.0     2054
# 3       480       234       4.0       3.0     1101
# 4       480       234       3.5       4.0     1784
# 5       480       234       3.5       3.0     1370
#
#                                              title_x
# 0          Star Wars: Episode IV - A New Hope (1977)
# 1  Star Wars: Episode VI - Return of the Jedi (1983)
# 2                    Honey, I Shrunk the Kids (1989)
# 3                                     Top Gun (1986)
# 4                          As Good as It Gets (1997)
# 5                                  Die Hard 2 (1990)

# %%
plot(df_merge)

# %%
distancia(df_merge)
# Out:
# 1.1547005383792515

# %%
df_merge = compare_users(448,599)
df_merge
# Out:
#     userId_x  userId_y  rating_x  rating_y  movieId  \
# 0        448       599       5.0       5.0      260
# 1        448       599       3.0       3.0      316
# 2        448       599       5.0       5.0     1210
# 3        448       599       4.0       3.0     2054
# 4        448       599       4.0       5.0     2858
# 5        448       599       5.0       4.0     2019
# 6        448       599       4.0       2.5      410
# 7        448       599       4.0       3.5       10
# 8        448       599       1.0       2.0       65
# 9        448       599       2.0       1.0      355
# 10       448       599       2.5       2.5     1101
# 11       448       599       4.0       3.5     1784
# 12       448       599       4.0       3.0     5989
# 13       448       599       3.0       2.5    72998
# 14       448       599       3.0       2.5     1370
# 15       448       599       3.0       2.5     1608
# 16       448       599       4.0       2.5     2694
# ...

# %%
plot(df_merge)

# %%
df_merge['rating_x'].plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df_merge['rating_y'].plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df_merge[['rating_x','rating_y']].corr()
# Out:
#           rating_x  rating_y
# rating_x  1.000000  0.704162
# rating_y  0.704162  1.000000

# %%
df_merge = compare_users(599,414)

# %%
plot(df_merge)

# %%
df_merge['rating_x'].plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df_merge['rating_y'].plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df_merge[['rating_x','rating_y']].corr()
# Out:
#           rating_x  rating_y
# rating_x  1.000000  0.747556
# rating_y  0.747556  1.000000

# %%
# medir solapamiento?

# %%
def union(user_x,user_y):
    return df[(df['userId']==user_x) | (df['userId']==user_y)]

# %%
union(599,414)
# Out:
#      Unnamed: 0  userId  movieId  rating   timestamp  \
# 7          1738     414      260     5.0   961514667
# 13         1810     599      260     5.0  1498533468
# 16         2215     414      316     3.0   961515271
# 22         2261     599      316     3.0  1498521582
# 31         7692     414     1210     5.0   961436248
# ..          ...     ...      ...     ...         ...
# 243       75035     599     1672     2.5  1519172040
# 246       83470     414     4823     2.0  1135220835
# 249       83990     414    42738     3.0  1216150216
# 251       83994     599    42738     2.5  1498515505
# 255       98265     414     6816     4.0  1065799981
#
#                                                  title  \
# 7            Star Wars: Episode IV - A New Hope (1977)
# 13           Star Wars: Episode IV - A New Hope (1977)
# 16                                     Stargate (1994)
# 22                                     Stargate (1994)
# ...

# %%
# solapamiento 24/74
len(compare_users(599,414))
# Out:
# 33

# %%
len(union(599,414))
# Out:
# 74

# %%
33/74
# Out:
# 0.44594594594594594

# %%
# índice de jaccard | A ^ B | / | A U B |

# %%
users = set(df['userId'])

# %%
users
# Out:
# {67,
#  101,
#  132,
#  198,
#  212,
#  234,
#  279,
#  292,
#  307,
#  325,
#  414,
#  446,
#  448,
#  480,
#  514,
#  555,
#  573,
#  599,
#  603}

# %%
# yo soy 599 y quiero recomendaciones
usuario_a_recomendar = 599
distancias = {}
for user in users:
    df_merge = compare_users(usuario_a_recomendar, user)
    d = distancia(df_merge)
    distancias[user] = d

# %%
distancias
# Out:
# {514: 0.9842509842514764,
#  132: 1.7217101133134214,
#  279: 0.9128709291752769,
#  414: 0.9847319278346619,
#  292: 1.1870513506545997,
#  555: 1.224744871391589,
#  307: 1.0145993123917847,
#  573: 1.6719612870681382,
#  446: 0.7071067811865476,
#  448: 0.82915619758885,
#  67: 1.2747548783981961,
#  325: 0.9746794344808963,
#  198: 1.2100767390069582,
#  212: 1.4142135623730951,
#  599: 0.0,
#  603: 1.0335288182638247,
#  480: 0.9682458365518543,
#  101: 0.8660254037844386,
#  234: 0.6454972243679028}

# %%
df[(df['userId']==234) | (df['userId']==446)]
# Out:
#      Unnamed: 0  userId  movieId  rating   timestamp  \
# 3          1667     234      260     5.0  1004407958
# 17         2221     446      316     4.0   843839191
# 27         7637     234     1210     5.0  1004408002
# 42        11034     234     2054     4.0  1004409156
# 69        19674     446      368     3.0   843839504
# 71        22098     234     1907     5.0  1004409394
# 89        27470     446       10     3.0   843839232
# 94        28175     234       65     3.0  1001975877
# 105       31301     234      355     2.0  1001975853
# 114       33997     234     1101     3.0  1004408226
# 132       34466     234     1784     4.0  1004407785
# 155       43664     234     1370     3.0  1004408167
# 197       52404     234     2422     2.0  1004408829
# 254       91223     234     3287     2.0  1004409410
#
#                                                  title  \
# 3            Star Wars: Episode IV - A New Hope (1977)
# ...

# %%
df[(df['userId']==599)]
# Out:
#      Unnamed: 0  userId  movieId  rating   timestamp  \
# 13         1810     599      260     5.0  1498533468
# 22         2261     599      316     3.0  1498521582
# 37         7745     599     1210     5.0  1498533608
# 41         9061     599     1282     4.0  1498498952
# 48        11070     599     2054     3.0  1498524093
# 62        14046     599     2858     5.0  1498533774
# 70        19698     599      368     2.5  1498514705
# 76        22453     599     2019     4.0  1498498925
# 83        26577     599      410     2.5  1498516121
# 85        27367     599        7     2.5  1498514161
# 93        27506     599       10     3.5  1498500281
# 99        28190     599       65     2.0  1498511235
# 102       30682     599      314     2.5  1519259227
# 108       31324     599      355     1.0  1498503355
# 113       33676     599      991     3.5  1519233999
# 122       34046     599     1101     2.5  1519119750
# 130       34214     599     1584     2.0  1498510384
# ...
